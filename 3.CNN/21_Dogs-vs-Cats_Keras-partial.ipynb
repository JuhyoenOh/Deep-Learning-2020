# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path='dogs-vs-cats/train/'

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []  ## X 값
y_dogs, y_cats = [], [] ### Y값

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL)) ## 사이즈 재구성 ROW 와 COL은 위에서 설정함
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[:5]
# Out:
# [1, 1, 1, 1, 1]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
## One-Hot Encoding
y_train = tf.keras.utils.to_categorical(y_train, 2)

# %%
y_train.shape
# Out:
# (2222, 2)

# %% [markdown]
# ### Test set(dog12,cat12 만들기)

# %%
# Test set 만들기
dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (611 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL)) ## 사이즈 재구성 ROW 와 COL은 위에서 설정함
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (611 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_test)
# Out:
# 1222

# %%
y_test = tf.keras.utils.to_categorical(y_test, 2)

# %%
y_test.shape
# Out:
# (1222, 2)

# %% [markdown]
# ## 모델 설정

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dropout(.5),
    Dense(2, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 19,071,714
# Trainable params: 19,071,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ## 모델 학습

# %%
X_train.shape
# Out:
# (2222, 96, 96, 1)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2,
          callbacks=[checkpointer, early_stopping_callback])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.7536 - accuracy: 0.6040
# Epoch 00001: val_loss improved from inf to 1.20411, saving model to model/dogs_vs_cats-cnn-01-1.2041.hdf5
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.7515 - accuracy: 0.6055 - val_loss: 1.2041 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6557 - accuracy: 0.6239
# Epoch 00002: val_loss improved from 1.20411 to 1.01995, saving model to model/dogs_vs_cats-cnn-02-1.0199.hdf5
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.6554 - accuracy: 0.6252 - val_loss: 1.0199 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6534 - accuracy: 0.6256
# Epoch 00003: val_loss improved from 1.01995 to 0.89003, saving model to model/dogs_vs_cats-cnn-03-0.8900.hdf5
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.6526 - accuracy: 0.6263 - val_loss: 0.8900 - val_accuracy: 0.1034
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6439 - accuracy: 0.6489
# Epoch 00004: val_loss improved from 0.89003 to 0.77323, saving model to model/dogs_vs_cats-cnn-04-0.7732.hdf5
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.6440 - accuracy: 0.6488 - val_loss: 0.7732 - val_accuracy: 0.1034
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6189 - accuracy: 0.6670
# Epoch 00005: val_loss did not improve from 0.77323
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6187 - accuracy: 0.6669 - val_loss: 0.9685 - val_accuracy: 0.1730
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5773 - accuracy: 0.7102
# Epoch 00006: val_loss did not improve from 0.77323
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.5761 - accuracy: 0.7119 - val_loss: 0.8063 - val_accuracy: 0.3506
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4975 - accuracy: 0.7574
# Epoch 00007: val_loss improved from 0.77323 to 0.74967, saving model to model/dogs_vs_cats-cnn-07-0.7497.hdf5
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.4987 - accuracy: 0.7569 - val_loss: 0.7497 - val_accuracy: 0.5326
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4497 - accuracy: 0.7932
# Epoch 00008: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.4497 - accuracy: 0.7923 - val_loss: 0.9145 - val_accuracy: 0.4876
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3634 - accuracy: 0.8301
# Epoch 00009: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.3643 - accuracy: 0.8295 - val_loss: 0.9868 - val_accuracy: 0.5326
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2774 - accuracy: 0.8818
# Epoch 00010: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 15ms/sample - loss: 0.2789 - accuracy: 0.8801 - val_loss: 0.9944 - val_accuracy: 0.5865
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1999 - accuracy: 0.9284
# Epoch 00011: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.2002 - accuracy: 0.9285 - val_loss: 1.2043 - val_accuracy: 0.6315
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1060 - accuracy: 0.9625
# Epoch 00012: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.1060 - accuracy: 0.9629 - val_loss: 2.0549 - val_accuracy: 0.5483
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9773
# Epoch 00013: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 15ms/sample - loss: 0.0678 - accuracy: 0.9769 - val_loss: 2.8544 - val_accuracy: 0.5506
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9716
# Epoch 00014: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.0832 - accuracy: 0.9719 - val_loss: 1.5339 - val_accuracy: 0.6360
# Epoch 15/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9756
# Epoch 00015: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.0833 - accuracy: 0.9758 - val_loss: 2.0782 - val_accuracy: 0.4697
# Epoch 16/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9835
# Epoch 00016: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.0639 - accuracy: 0.9837 - val_loss: 1.8800 - val_accuracy: 0.5753
# Epoch 17/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9881
# Epoch 00017: val_loss did not improve from 0.74967
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.0368 - accuracy: 0.9882 - val_loss: 3.7111 - val_accuracy: 0.4360

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-07-0.7497.hdf5')

# %%
scores = model.evaluate(X_train, y_train, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 2222/2222 - 5s - loss: 0.5062 - accuracy: 0.7624
# MODEL ACCURACY: 0.76238

# %%
scores = model.evaluate(X_test, y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 1222/1222 - 3s - loss: 0.6479 - accuracy: 0.6424
# MODEL ACCURACY: 0.64239
